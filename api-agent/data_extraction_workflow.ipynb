# %%
from typing import Dict
from pydantic_ai import Agent
from eicat_ai import agents
from eicat_ai.models import Paper
from eicat_ai.converters import pdf_to_markdown

# %% [markdown]
# First define a list of potential models to test the agent with.

# %%
models: Dict[str, str] = {
    "nova-lite": "bedrock:amazon.nova-lite-v1:0",
	"nova-pro": "bedrock:amazon.nova-pro-v1:0",
    "claude": "bedrock:anthropic.claude-3-7-sonnet-20250219-v1:0",
}

# %% [markdown]
# Next create the agent with your selected model.

# %%
paper_agent: Agent[None, Paper] = agents.paper_agent(models["claude"])

# %% [markdown]
# Use the agent to convert a PDF into the expected pydantic model output.

# %%
paper: Paper = await pdf_to_markdown(paper_agent, "../data/single-eval/Garrett/Competition_or_co-existence.pdf")

# %% [markdown]
# Save the output to JSON so it can be re-read late.

# %%
paper.save("../data/single-eval/Garrett/paper.json")

# %% [markdown]
# Reload the paper if it has already been saved.

# %%
p: Paper = Paper.load("../data/single-eval/Garrett/paper.json")

# %%
from IPython.display import display, Markdown
display(Markdown(p.content))
# Out:
# # Competition or co-existence of reintroduced, critically endangered Mauritius fodies and invasive Madagascar fodies in lowland Mauritius?
#
# ## Abstract
#
# Habitat destruction and introductions of invasive species have been primary causes of endemic species loss on oceanic islands. This paper addresses the question of whether a reintroduced population of a critically endangered island endemic, the Mauritius fody (Foudia rubra) is competing or co-existing with an exotic congener, the Madagascar fody (F. madagascariensis). We investigated habitat use and feeding ecology of the Mauritius fody during two early phases of its reintroduction onto a restored islet, and compared these parameters with the sympatric population of Madagascar fodies. The number of Mauritius fody territories increased from 4 to 20 in a seven month period following release, and overall mean territory area (c. 1 ha) was significantly larger than that of the more abundant Madagascar fody (c. 0.07 ha). The initial four territories were located in mature coastal forest, whilst those of the Madagascar fody were characterised by open canopy, smaller trees and grass-dominated ground cover. Mauritius fodies foraged mainly in dead leaves for insects, whilst the Madagascar fody fed primarily on the seeds of a native grass species. Mauritius fody territories later expanded to include a range of habitats. Differing ecological requirements indicate that divergence between these congeners may be sufficient for them to coexist and exploit contrasting resources on restored islets. We discuss the implications of these findings for both the long-term restoration of the Mauritius fody and other avian recovery programmes and highlight the critical importance of long-term post-release monitoring to assess the success of reintroduction to offshore islets as a long-term conservation strategy.
#
# ## Introduction
#
# Oceanic islands are characterized by high levels of biodiversity and species endemism (Alder, 1994) and endemic island taxa currently rank amongst those of greatest conservation priority (Biber, 2002). The introduction of exotic species by human colonizers together with habitat destruction have been the primary causes of species decline in these uniquely evolved island communities (Dulloo et al., 2002; Wanless et al., 2002; Norris and Harper, 2004; Watson et al., 2004). The geographical isolation of island communities, which evolved in the absence of competitor species, has increased their susceptibility to competitive exclusion by newly arrived exotics (Fritts and Rodda, 1998; Manne et al., 1999; Carter and Bright, 2002).
#
# The islands of the Indian Ocean have been highlighted as one of the 'biodiversity hotspots' for species conservation (Myers et al., 2000; Brooks et al., 2002) including Mauritius, one of the Mascarene Islands, 890 km east of Madagascar. The island's flora and fauna have suffered extensive degradation since human colonization, with a loss of over 95% of native forest cover (Safford, 1997a) together with 16 or more species of endemic and native birds (Cheke, 1987a). A further eight of the remaining nine native avian species are threatened with extinction (IUCN, 2006). Recent successful, integrated recovery programmes conducted jointly by the Mauritian Wildlife Foundation (MWF) and the Mauritian National Parks and Conservation Service (NPCS), have targeted four different endemic avian species: the Mauritius kestrel (Falco punctatus), the pink pigeon (Columba mayeri), the echo parakeet (Psittacula eques) (Jones and Hartley, 1995) and, most recently, a small passerine, the Mauritius fody (Foudia rubra) (Cristinacce et al., 2005).
#
# Fodies (Foudia sp.) are small weaver birds (family Ploceidae), endemic to the islands of the western Indian Ocean. Of the six extant species, two are threatened, namely the Rodrigues fody (F. flavicans) (Vulnerable) and the Mauritius fody (Critically endangered) and a third, the Seychelles fody (F. sechellarum), has recently been downgraded to Near Threatened (IUCN, 2006). The Madagascar fody (F. madagasceriensis) has the most widespread distribution of the six species (Moreau, 1960), occurring across nearly the entire region. The Comoro fody (F. eminentissima) occurs as restricted races on several Comoros islands and Aldabra (Adriansen et al., 2001). The forest fody (F. omissa), found in eastern Madagascar (Rand, 1936) is sometimes classed as a subspecies of F. eminentissima and a seventh species, the Réunion fody (unnamed), is already extinct (Cheke, 1987a).
#
# The population of the Mauritius fody fell from around 250 pairs in 1975 to 120 in 1993 (Safford, 1997c,e), and was restricted to a small area of upland forest (Safford, 1997b). Population size appears to have stabilized at around 120 pairs although there has been some dispersal to nearby pine plantations (Nichols et al., 2002). This reduction in numbers and range has been attributed to large-scale habitat destruction and nest failure due to introduced predators including the black rat (Rattus rattus) and crab-eating macaque (Macaca fascicularis) (Safford, 1997a,d). A captive breeding program for the Mauritius fody was established at the Gerald Durrell Endemic Wildlife Sanctuary (GDEWS) in Black River, Mauritius in 2002, using young collected from upland nests judged likely to fail (Switzer et al., 2003). The first captive-reared Mauritius fodies were released onto Ile aux Aigrettes, a small, predator-free, offshore islet in 2003 (Cristinacce, 2004) and the population size on this islet is currently (January 2007) c. 130 birds.
#
# There has been some question as to the possible interaction between the Mauritius fody and the introduced Madagascar fody, which is now widely distributed across Mauritius (Newton, 1958; Cheke, 1987b). However, previous assessment of the nature of the co-existence of these two congeners has been based on anecdotal observations. The establishment of a conservation programme to increase numbers of the endangered Mauritius fody by release onto predator-free offshore islets where high densities of exotic Madagascar fodies may occur, highlighted the need for quantitative research into this relationship in coastal, lowland habitat. The present research set out to examine the ecology of released, endemic Mauritius fodies and introduced Madagascar fodies occurring sympatrically in lowland habitat on an offshore Mauritian islet. The specific aims of this study were: (1) to investigate food preferences and the size, distribution and habitat characteristics of territories established by reintroduced Mauritius fodies during two early phases of the reintroduction programme; (2) to compare these parameters in the population of exotic Madagascar fodies which has naturally colonized the islet from the introduced population on the mainland; (3) to consider the implications of the results for both the long-term restoration of the Mauritius fody and other avian recovery programmes for critically-endangered species where sympatric populations of exotic congeners occur. Due to their absence from lowland habitat for over 300 years, this study is the first to investigate feeding preferences and habitat requirements of the Mauritius fody, in an environment from which exotic mammalian predators have been removed and native coastal forest restored.
#
# ## Methods
#
# ### Study area
#
# Ile aux Aigrettes (IAA), a small 26 ha coralline limestone islet with a maximum elevation of 12 m, 625 m from the southeast coast of Mauritius (Fig. 1), was chosen as the Mauritius fody release site. A continuing habitat recovery programme has re-established a wide range of indigenous Mauritian flora on this islet where shallow soils restrict forest canopy height to fairly low levels (Parnell et al., 1989). Much of the island is covered by coastal scrub vegetation, dominated by small trees and shrubs including Ehretia petiolaris, Tarenna borbonica, and Scaevola taccada, with an average height of 2.5 m. Areas of mature canopy forest, with an average height of 4–5 m but some trees reaching 7–8 m, are dominated by lowland ebony Diospyros egrettarum, together with Dracaena concinna, Gastonia mauritiana and Euginia lucida, and have an almost continuous ground cover of the native fern Phymatodes scolopendria (Parnell et al., 1989). Leucaena leucocephala is the most problematic exotic species, forming monospecific stands which outcompete the native flora, but is kept under control by regular weeding. Exotic mammalian nest predators (black rats and crab-eating macaques), the main cause of decline in the upland Mauritius fody (Safford, 1997d), have been eradicated (Varnham et al., 2002) or were never present. The island is marked into a 12.5 m² grid system with pegs driven into the surface substrate.
#
# ### Species characteristics
#
# In addition to differences in plumage colouration, the Mauritius fody has a thinner, longer, more pointed bill and a more developed brush tongue than the Madagascar fody (Newton, 1958; Crook, 1961; Frith, 1976; Cheke, 1987b). Both species have distinctive territorial calls and an array of other vocalizations (Safford, 1997c). On mainland Mauritius, Mauritius fodies defend year-round territories (Safford, 1991, 1997d), whereas, Madagascar fodies only hold territories during the breeding season, forming flocks during the non-breeding period (Newton, 1958; Greig-Smith, 1982; Cheke, 1987b). In upland forests, breeding extends from late August to early April in the Mauritius fody (Safford, 1997c) and from December possibly through to early May in the Madagascar fody, although the latter species has been observed in breeding plumage throughout the year (Cheke, 1987b). On Ile aux Aigrettes, the main breeding period for the Mauritius fody extends from early July to February, and from December to June in the Madagascar fody with some birds occasionally breeding outside this period (A. Cristinacce, personal observation).
#
# ### Mauritius fody reintroduction programme on Ile aux Aigrettes
#
# Captive-reared Mauritius fodies were first released onto Ile aux Aigrettes in 2003 and the first successful breeding occurred in 2004. The last captive-reared birds were released in March 2006. At the start of the initial study period (SP1), April to July 2005, a total of 47 Mauritius fodies, 28 males and 19 females, were present on Ile aux Aigrettes and during the second study period (SP2), November 2005 to February 2006, population size increased from 88 birds (24 males, 19 females and 45 juveniles) at the end of December to 97 birds by end of February (25 males, 20 females, and 52 juveniles). Birds were provided with supplementary food at feeding stations within the aviaries used in the release programme to which birds had access through open hatches. The birds were monitored continually throughout the release programme by at least one full time field worker and all Mauritius fodies are ringed for individual identification. None of the Madagascar fodies on Ile aux Aigrettes were ringed at the time of this study.
#
# ### Territory mapping and habitat composition
#
# Parameters of territory size and habitat composition were recorded for Mauritius fodies during both SP1 and SP2 whilst those of the Madagascar fodies were only studied during SP1. The territorial boundaries of all male Mauritius fodies, plus those of a random sample of 20 Madagascar fodies, were identified from territorial vocalizations. The location of territorial calls observed at the furthest point of an individual's defended territory, were recorded using a handheld GARMIN etrex GPS device. Territorial male Mauritius fodies were most vocal between dawn (c. 06:00 h) and approximately 10:00 h whilst territorial displays by Madagascar male fodies continued throughout the day. Vegetation cover within the territory of each fody species was assessed using two straight-line transects, along the entire length of the territory, at right angles to the territory edge, in SP1. Due to the increased number and size of Mauritius fody territories during SP2, two transects each of 50 m in length, were used to assess habitat composition in each territory over that time period. At four metre intervals along each transect, individual trees with a basal circumference of >10 cm were measured within an area 2.5 m × 40 cm wide either side of the transect line. The following parameters were recorded for each tree: species identity, height, basal circumference and canopy diameter.
#
# Ground cover was assessed using 1 m² quadrats to estimate the percentage cover of each plant species less than 50 cm in height. A total of 20 quadrats were placed at random within Madagascar fody territories, and 40 quadrats sampled within Mauritius fody territories in SP1. Canopy cover was estimated using a spherical densiometer, at 20 random points within Madagascar fody territories, 40 in Mauritius fody territories in SP1 and 20 in SP2.
#
# ### Foraging behaviour
#
# Foraging behaviour was investigated between April and July 2005. Feeding behaviour was assessed within six permanent and evenly spaced transects distributed across the east to west length of the island. Transects were walked on three occasions during each of the following four time periods: early morning (06:00–09:00 h), late morning (09:00–12:00 h), early afternoon (12:00–15:00 h) and late afternoon (15:00–18:00 h). The following data were recorded for every Mauritius and Madagascar fody foraging event observed: food item consumed (insect, nectar, fruit, seeds, egg, or plant material), height above ground, and the part of the plant involved (live leaf, dead leaf, branch, trunk, flower or fruit). Foraging events were recorded so that no individual was recorded more than once during any transect. When an individual was seen foraging on bark or leaves, the prey item was recorded as insect, since these were the prey items usually taken at these sites, although it was often not possible to determine whether an insect had been captured.
#
# ### Data analysis
#
# GPS points were downloaded into ArcView GIS and joined to form Minimum Convex Polygons (Breslin et al., 1999) and territory area calculated using the Arcview extension; Animal Movements. Tree canopy diameter was converted into tree canopy area using trigonometry, and tree basal circumference was similarly converted into tree basal area; t-tests were used to compare these parameters within Mauritius and Madagascar fody territories. To determine the density of each tree species within each fody territory, the total number of trees of each species counted along each vegetation transect was divided by the total transect area (2.5 m × 40 cm × 2) multiplied by the number of 4 m intervals in each transect. Mann–Whitney U-tests or t-tests were used to compare the density of each tree species and the percentage cover of each ground cover category within territories of the two fody species.
#
# ## Results
#
# ### Territory size and habitat composition
#
# Four of the 28 Mauritius fody males were defending territories in SP1 (Fig. 2a) and all four were males over one year of age. The maps plotted for SP2 show the territories at the end of December when 20 of 24 males held territories (Fig. 2b). Mauritius fody territories in SP1 and SP2 were significantly larger than those defended by Madagascar fodies measured in SP1. Mean (±SE) area (m²) of Mauritius fody territories in SP1 was 9408.1 ± 1157.2, compared to 704.9 ± 60.2 for Madagascar fodies (z = 3.1, n = 24, p < 0.001). In SP2 the mean area of Mauritius fody territories was 10098 m² ± 1036.2 (z = 5.41, n = 40, p < 0.001).
#
# In SP1, it was found that the territories of the first four Mauritius fodies contained taller trees and had a higher percentage of canopy cover than those of the Madagascar fody (Table 1). No difference in basal tree area was evident in territories of the two species. The number of trees per m² was significantly higher in Madagascar than Mauritius fody territories (mean ± SE, Mauritius fody: 0.19 ± 0.03, Madagascar fody: 0.32 ± 0.02, z = 3.47, n = 231, p < 0.001). Madagascar fody territories also had a significantly higher abundance of Ehretia petiolaris, Dodonea viscosa, Hibiscus tiliaceous, and 'other trees', per m², but a similar abundance of Tarenna borbonica, Diospyros egrettarum, Maytenus pyria, Gastonia mauritiana, Euginia lucida, and Dracaena concinna (Table 2). Percentage ground cover of the native fern Phymatodes scolopendria was significantly higher in territories defended by Mauritius fodies (Table 3), while ground flora composition was dominated by the native grass Stenotaphrum micranthum and the exotic herb Stachytarpheta jamaicensis in Madagascar fody territories (Table 3).
#
# During SP2, the number of Mauritius fody territories had expanded to cover most of the islet, and there was no significant difference in either the number of trees per m² within these territories (mean ± SE, Mauritius fody: 0.28 ± 0.02, Madagascar fody: 0.32 ± 0.02, z = 1.15, n = 396, p > 0.05) or the dimensions of these trees compared to those within Madagascar fody territories (Table 1). Ground flora composition in Mauritius fody territories in SP1 had significantly higher cover of dead leaves (leaf litter), and lower abundance of the grass Stenotaphrum micranthum and the herb Stachytarpheta jamaicensis compared with Madagascar fody territories (Table 3).
#
# ### Foraging behaviour
#
# Dietary composition differed significantly between Mauritius and Madagascar fodies (χ² = 164.7, d.f. = 5, p < 0.001) (Fig. 3). Mauritius fodies were predominantly insectivorous and Madagascar fodies primarily seed eaters. Observation of Mauritius fodies found that 129 of 166 (78%) foraging events targeted insects, mainly on dead leaves, whereas seeds contributed the largest part of the dietary intake of the Madagascar fody (72/112; 59%, of foraging events observed during transect walks; Fig. 3). Fruit, nectar and plant material formed similar percentages of the diet in both species. A Mauritius fody was also observed feeding on a barred ground dove (Geopelia striata) egg on one occasion.
#
# Plant species targeted during foraging events differed significantly between Mauritius and Madagascar fodies (χ² = 187.4, d.f. = 11, p < 0.001; Fig. 4). Madagascar fodies showed a marked preference for one particular species of grass, with 63.4% (71/112) of the feeding observations focused on Stenotaphrum micranthum. The Mauritius fody used the trees Ehretia petiolaris, Tarenna borbonica and Diospyros egrettarum and Dracaena concinna in the highest proportions (Fig. 4).
#
# ## Discussion
#
# This study set out to investigate whether there was any evidence for competition between reintroduced Mauritius fodies and the abundant, exotic congener, the Madagascar fody during the initial phase of a reintroduction programme onto a predator-free, offshore islet. We investigated feeding behaviour and the size and distribution of fody territories during two early phases in this restoration programme. The number of Mauritius fody territories increased from four in April to June 2005, to 20 in December 2005. The initial four territories established by adult pairs were located in areas of relatively mature, coastal forest, but five months later, territories had expanded to include a range of habitats distributed across most of the islet with minimal changes in mean territory area (0.9 ha to 1 ha). Habitat in the four original territories was characterised by areas of higher canopy cover, taller trees and a greater abundance of fern and leaf litter ground cover, whilst randomly sampled Madagascar fody territories occurred in areas of younger forest, characterized by open canopy and a greater density of smaller trees with a grass-dominated ground cover. Differences in microhabitat requirements were also indicated by contrasting feeding behaviour in the two species: the Mauritius fodies foraged mainly on insects in dead leaves from ground to canopy level while the introduced fodies were primarily granivorous, foraging mainly in the understorey. With increased population size and numbers of Mauritus fody territories in November to December, the significant interspecific differences in the number of trees within territories disappeared.
#
# ### Territory size and habitat composition
#
# Madagascar fodies are only territorial during their breeding season, which extends mainly from December to June on Ile aux Aigrettes, while Mauritius fodies defend permanent territories, thus the timing of the two separate study periods allowed comparison of territory parameters in both species.
#
# Mauritius fody territories were approximately two orders of magnitude larger (c. 1 ha) than those of the Madagascar fodies (c. 0.07 ha). This territory size difference may be due to the higher abundance of Madagascar fodies present on Ile aux Aigrettes and the more permanent occupancy of Mauritius fody territories. Only a random sample of Madagascar fody territories was mapped accurately in this study, but it should be noted that the territories within this large population occur contiguously or in clusters on Ile aux Aigrettes. Previous research on the Madagascar fody in the Seychelles found similar territory size to that observed in this study, with a radius of around 10–30 m (Crook, 1961). In upland forest habitat on mainland Mauritius, Safford (1997c) reported average Mauritius fody territories of 4–5 ha in sparsely populated areas, but in high quality habitat these may be reduced to 0.9 ha areas (Safford, 1997d). The latter author also observed that pairs spent most of their time within their territories throughout the year, utilizing them for food resources as well as breeding sites. The provision of supplementary food for the reintroduced Mauritius fodies on Ile aux Aigrettes may enable the fodies to survive in smaller territories and territory size is likely to decrease further as population size increases, as reported in the Seychelles fody (Kraaijeveld and Komdeur, 2003). Changes in the social behaviour of Seychelles fodies were also noted in the higher density population on Cousine Island, including the occurrence of cooperative breeding and large flocks of non-breeding birds and similar shifts in social behaviour of marooned populations with increasing population size, have also been reported in other avian species (Komdeur et al., 1995). This type of behavioural change highlights the importance of continued monitoring of territorial distribution and patterns of juvenile dispersal in reintroduced populations like the Mauritius fody on Ile aux Aigrettes where every bird can be ringed and life history data collected.
#
# Initially, the areas selected as territories by reintroduced Mauritius fodies were located in mature forest with higher canopy cover and taller trees. Impey et al. (2002) similarly found that the distribution of the threatened Rodrigues fody (F. flavicans) correlated with tree height and canopy cover in fragmented remnant habitat on Rodrigues. Madagascar fody territories contained higher abundances of the dominant scrub species Ehretia petiolaris, Dodonea viscosa, which is often used for nesting and Hibiscus tiliaceous, which is patchily distributed around the islet's coast. By the second study period, when the Mauritius fody population had expanded to occupy territories across most of the islet, differences in the cover of these three plant species were no longer apparent. It will be interesting to monitor how native forest regeneration, increased canopy cover and decline in open areas on Ile aux Aigrettes influences the success of Madagascar fodies. It has been suggested that numbers of Madagascar fodies are likely to decline with a decrease in open areas.
#
# ### Feeding behaviour
#
# Observations of feeding behaviour indicated that the reintroduced population of Mauritius fodies was primarily insectivorous (around 78% of their foraging was on insects) but they also ate fruit, nectar, seeds, plant material, and even egg. These results confirm similar findings of chiefly insectivorous behaviour for upland Mauritius fodies in previous studies (Newton, 1958; Cheke, 1987b; Safford, 1991, 1997c). The supplementary feeding stations were not included in the transect walks conducted during the present study, which focused on the natural food items targeted by both species. There is no previous documented evidence for seeds, plant material (including sap and flowers) or egg being consumed by the Mauritius fody. Vertebrate egg predation by the Mauritius fody has also been observed on Ile aux Aigrettes, on the eggs of introduced red-whiskered bulbuls (Pycnonotus jocosus) and the endemic day gecko (Phelsuma ornata) (A. Cristinacce, personal observation), and has been similarly recorded in the Seychelles fody (Veen et al., 2000), which also scavenges on fish dropped by sea birds (Prys-Jones and Diamond, 1984). The latter study also indicated similar insectivorous foraging in the Seychelles fody, where insects contributed 69% of their diet.
#
# The most common substrate used for foraging by the Mauritius fodies was dead leaves, most frequently of the plant species Ehretia petiolaris and Diospyros egrettarum, which were searched for insects. Foraging behaviour recorded in upland Mauritius fodies was mainly probing and stripping bark and moss (Cheke, 1987b; Safford, 1991) and relates to differing species composition between the wetter upland forest and the drier, coastal, broad-leafed forest on Ile aux Aigrettes.
#
# The primarily granivorous (64%), but also varied (nectar, insects, fruits and young leaves), diet of the introduced Madagascar fody found here confirms previous findings for the species in the Seychelles and mainland Mauritius (Crook, 1961; Prys-Jones and Diamond, 1984; Cheke, 1987b).
#
# On Ile aux Aigrettes, the Madagascar fodies obtained almost their entire seed intake from one species of grass Stenotaphrum micranthum during the April to June study period, despite an abundance of other grasses. Many of these other grasses were also flowering and seeding during the study, but only two feeding observations on the seeds of one other species (Rhynchelytrum repens) were recorded. Preference for S. micranthum may be related to the biology of the Stenotaphrum genus, of which two species are native to Mauritius (S. micranthum and S. didiatum). Stenotaphrum micranthum is an annual, with a narrow spike-like inflorescence and racemes sunken in depressions on opposite sides of the main axis (Hubbard and Vaughan, 1940). The latter can be easily broken off in sections and accessed from ground level. The flowering period for grasses in Mauritius typically extends from March to May following heavy rain (Hubbard and Vaughan, 1940), although during this study, flowering and seeding continued into July. This corresponded with the main breeding period of the Madagascar fody, and supports previous findings in the Seychelles, where the Madagascar fody breeding season also coincides with highest seed abundance (August to April) (Prys-Jones and Diamond, 1984). It would be useful to investigate whether greater dietary overlap and competition for food occurs between the Madagascar and Mauritius fody outside the grass seeding season during the driest months of the year (October to December) when Mauritius fodies are rearing young and may be more affected by competition for insects.
#
# ### Competition/coexistence and hybridization
#
# This study found significant differences in the feeding and habitat requirements of Mauritius fodies and Madagascar fodies on Ile aux Aigrettes. The Mauritius fody favours areas with mature and semi-mature forest and good canopy cover, and exploits an insect-rich diet. This adaptation is not surprising given that Mauritius was formerly almost entirely covered by forest. In contrast, the Madagascar fody is typically a grassland bird, frequenting areas of open, immature forest and forest edges (Rand, 1936; Newton, 1958; Moreau, 1960). Our results support the hypothesis that the divergence between the two species is sufficient for them to coexist and exploit different resources on restored offshore islets.
#
# Large variation in bill length and size occurs within the genus Foudia (Crook, 1961). The large, thick bill of the Madagascar fody is adapted for the open savannah of its native habitat (Moreau, 1960) and large scale destruction of the native Mauritian forests has simultaneously facilitated population expansion of the latter and decline of the forest-dependent Mauritius fody. Jones (1996) argued that the Madagascar fody and other exotic birds were primarily occupying human-modified areas and excluding their congeners, while native species are more dominant in the native forest where they are better adapted. The slight overlap in the breeding periods of the two species on Ile aux Aigrettes, and courtship displays by male Madagascar fodies towards female Mauritius fodies observed during this study, highlights the risk of hybridization during the months concerned i.e. December to February and possibly September and October. It is important that monitoring of the released population continues, in order to identify any hybrids and changes in interspecific interactions. Hybridization has been reported between the Seychelles and Madagascar fodies and similarly documented between the Madagascar fody and the Madagascar Forest fody F. omissa (Lucking, 1997; Dee, 1986).
#
# The successful spread of the Madagascar fody throughout the Indian Ocean is often attributed to its adaptable feeding characteristics (Frith, 1976; Cheke, 1987b). However, its successful range expansion across the Indian Ocean is more likely a consequence of its apparent capacity to breed successfully in the presence of introduced black rats and to the large-scale degradation and conversion of native forest to open habitats which has occurred since human colonization (Jones, 1996), rather than due to it being a generalist feeder. Specialization to forest life, and a diet high in insects and nectar, has favoured the evolution of a narrow bill in the Mauritius fody (Newton, 1958), which may have restricted the distribution of the species in the changing landscape of Mauritius (Vaughan and Wiehe, 1937; Hubbard and Vaughan, 1940). These forest adaptations, also seen in the Rodrigues and Seychelles fodies may have increased the vulnerability of these fodies to extinction by rapid habitat destruction.
#
# ## Conclusions and future management recommendations
#
# This self-contained, reintroduced subpopulation of Mauritius fodies provides an excellent opportunity for the continued monitoring of its population biology, feeding ecology and social organisation over time. Moreover, it provides baseline habitat data with which to assess the suitability of other offshore islands or mainland areas for future reintroductions of this charismatic, endangered endemic species.
#
# Initial results suggest that the Mauritius fody is capable of survival in predator-free and restored lowland forest, from which it has been absent for over 300 years and that Ile aux Aigrettes has the potential to support a population of Mauritius fodies. Recovery of the Seychelles fody on Cousin Island, following habitat restoration, indicates that an island of similar size to Ile aux Aigrettes is capable of supporting several hundred birds (Brooke, 1985).
#
# Reintroduction has now played an important role in the conservation of several threatened oceanic island passerine species including the New Zealand hihi (Notiomystis cincta) (Armstrong et al., 1999), New Zealand saddlebacks (Philesturnus carunculatus) (Lovegrove, 1996), and the Seychelles warbler (Acrocephalus sechellensis) (Komdeur et al., 1995; Henri et al., 2004). This study has highlighted the potential of species restoration programmes which increase the range and security of threatened species. Post-release monitoring during the early stages of establishment is vital to determine the success and long-term management of reintroduced populations (Armstrong et al., 1999; Jones, 2004; Tweed et al., 2003).

# %% [markdown]
# Create an agent for extracting EICAT impacts from the paper.

# %%
from eicat_ai.agents import data_extraction_agent
from eicat_ai.models import Impact
from typing import List

de: Agent[Paper, List[Impact]] = data_extraction_agent(models["claude"])

# %% [markdown]
# Run the agent requesting it extract the all impacts and providing the extracted paper as a dependency.

# %%
result = await de.run(["Extract all impacts for me"], deps=p)

# %% [markdown]
# Save the resulting output to csv.

# %%
Impact.save_to_csv(result.output, "../data/Gozlan_impacts.csv")
